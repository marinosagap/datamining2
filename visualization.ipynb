# %% [markdown]
# # Part 1 -- Visualisation

# %% [markdown]
# The libraries that we are going to use:

# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %% [markdown]
# We read our data:

# %%
mydata = pd.read_csv(sep='\t',filepath_or_buffer='train.tsv')

# %%
mydata.head()
# Out:
#   Attribute1  Attribute2 Attribute3 Attribute4  Attribute5 Attribute6  \
# 0        A11           6        A34        A43        1169        A65
# 1        A12          48        A32        A43        5951        A61
# 2        A14          12        A34        A46        2096        A61
# 3        A11          42        A32        A42        7882        A61
# 4        A11          24        A33        A40        4870        A61
#
#   Attribute7  Attribute8 Attribute9 Attribute10  ...    Attribute13  \
# 0        A75           4        A93        A101  ...             67
# 1        A73           2        A92        A101  ...             22
# 2        A74           2        A93        A101  ...             49
# 3        A74           2        A93        A103  ...             45
# 4        A73           3        A93        A101  ...             53
#
#   Attribute14  Attribute15 Attribute16 Attribute17  Attribute18 Attribute19  \
# ...

# %%
set(mydata['Attribute14'])
# Out:
# {'A141', 'A142', 'A143'}

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# We preprocess our data and we encode the various attributes

# %%
#preprocessing
proccessedData = mydata #gia kathe attribute an einai categorical to kanoume aplh antistoixish se numerical

#kanoume encode to attribute1
integer_map1 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute1']))])  
for x in set(mydata['Attribute1']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map1[x])
print(integer_map1)

#kanoume encode to attribute3
integer_map3 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute3']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute3']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map3[x])
print(integer_map3)

#kanoume encode to attribute4
integer_map4 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute4']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute4']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map4[x])
print(integer_map4)
     
#kanoume encode to attribute6
integer_map6 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute6']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute6']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map6[x])
print(integer_map6)

#kanoume encode to attribute7
integer_map7 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute7']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute7']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map7[x])
print(integer_map7)

#kanoume encode to attribute9
integer_map9 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute9']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute9']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map9[x])
print(integer_map9)
    
#kanoume encode to attribute10
integer_map10 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute10']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute10']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map10[x])
print(integer_map10)
    
#kanoume encode to attribute12
integer_map12 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute12']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute12']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map12[x])
print(integer_map12)
    
#kanoume encode to attribute14
integer_map14 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute14']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute14']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map14[x])
print(integer_map14)
        
#kanoume encode to attribute15
integer_map15 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute15']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute15']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map15[x])
print(integer_map15)

#kanoume encode to attribute17
integer_map17 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute17']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute17']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map17[x])
print(integer_map17)
    
#kanoume encode to attribute19
integer_map19 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute19']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute19']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map19[x])
print(integer_map19)
    
#kanoume encode to attribute20
integer_map20 = dict([(val, i) for i, val in enumerate(set(proccessedData['Attribute20']))])  #kanoume encode to attribute1
for x in set(mydata['Attribute20']): #antikathistoume kathe ena me ton antistoixo arithmo sto integer map
    proccessedData = proccessedData.replace(x, integer_map20[x])
print(integer_map20)
# Out:
# {'A14': 0, 'A11': 1, 'A13': 2, 'A12': 3}
# {'A33': 0, 'A32': 1, 'A31': 2, 'A30': 3, 'A34': 4}
# {'A410': 0, 'A46': 1, 'A44': 2, 'A45': 3, 'A42': 4, 'A43': 5, 'A40': 6, 'A41': 7, 'A48': 8, 'A49': 9}
# {'A64': 0, 'A65': 1, 'A61': 2, 'A62': 3, 'A63': 4}
# {'A75': 0, 'A74': 1, 'A73': 2, 'A72': 3, 'A71': 4}
# {'A94': 0, 'A91': 1, 'A93': 2, 'A92': 3}
# {'A102': 0, 'A103': 1, 'A101': 2}
# {'A121': 0, 'A122': 1, 'A123': 2, 'A124': 3}
# {'A142': 0, 'A143': 1, 'A141': 2}
# {'A151': 0, 'A153': 1, 'A152': 2}
# {'A174': 0, 'A173': 1, 'A172': 2, 'A171': 3}
# {'A191': 0, 'A192': 1}
# {'A201': 0, 'A202': 1}

# %%
set(mydata['Attribute1'])
# Out:
# {'A11', 'A12', 'A13', 'A14'}

# %%
# map attribute's one data to a dictionary
count = 0;
mymap = []
data = set(mydata['Attribute1'])
print(data)
print(sorted(data))
for x in sorted(data):
    mymap.append(count);
    print(x)
    count+=1
print(mymap)
# Out:
# set(['A14', 'A11', 'A13', 'A12'])
# ['A11', 'A12', 'A13', 'A14']
# A11
# A12
# A13
# A14
# [0, 1, 2, 3]

# %%
proccessedData.head()
Bad = proccessedData[proccessedData['Label']==2]
Good = proccessedData[proccessedData['Label']==1]

# %% [markdown]
# ## Printing our Plots

# %% [markdown]
# ### Categorical Data Plots

# %%
#kanoume ola ta data arithmous gia na mporoume na ftiaksoume to histogram
Good.head()
# Out:
#    Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 0           1           6           4           5        1169           1
# 2           0          12           4           1        2096           2
# 3           1          42           1           4        7882           2
# 5           0          36           1           1        9055           1
# 6           0          24           1           4        2835           4
#
#    Attribute7  Attribute8  Attribute9  Attribute10  ...    Attribute13  \
# 0           0           4           2            2  ...             67
# 2           1           2           2            2  ...             49
# 3           1           2           2            1  ...             45
# 5           2           2           2            2  ...             35
# 6           0           3           2            2  ...             53
#
#    Attribute14  Attribute15  Attribute16  Attribute17  Attribute18  \
# ...

# %%
# the histogram of the categorical data of Attribute 1 -- Good and Bad
print("Encoding : ", integer_map1)

df = pd.DataFrame({'Good':Good["Attribute1"],'Bad':Bad["Attribute1"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute1")
plt.ylabel('Status of existing checking account')
plt.xlabel('A13              A11                 A12                 A14')
plt.show()
# Out:
# ('Encoding : ', {'A14': 0, 'A11': 1, 'A13': 2, 'A12': 3})

# %%
# the histogram of the categorical data of Attribute 3 -- Good and Bad
print("Encoding : ", integer_map3)

df = pd.DataFrame({'Good':Good["Attribute3"],'Bad':Bad["Attribute3"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute3")
plt.ylabel('Credit history')
plt.xlabel('A31         A32              A33             A34       A30')
plt.show()
# Out:
# ('Encoding : ', {'A33': 0, 'A32': 1, 'A31': 2, 'A30': 3, 'A34': 4})

# %%
# the histogram of the categorical data of Attribute 4 -- Good and Bad
print("Encoding : ", integer_map4)

df = pd.DataFrame({'Good':Good["Attribute4"],'Bad':Bad["Attribute4"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute4")
plt.ylabel('Purpose')
plt.xlabel('A43   A46   A42   A41    A44   A410    A45   A48   A49   ')
plt.show()
# Out:
# ('Encoding : ', {'A410': 0, 'A46': 1, 'A44': 2, 'A45': 3, 'A42': 4, 'A43': 5, 'A40': 6, 'A41': 7, 'A48': 8, 'A49': 9})

# %%
# the histogram of the categorical data of Attribute 6 -- Good and Bad
print("Encoding : ", integer_map6)

df = pd.DataFrame({'Good':Good["Attribute6"],'Bad':Bad["Attribute6"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute6")
plt.ylabel('Savings account/bonds')
plt.xlabel('A62            A64            A61             A63            A65 ')
plt.show()
# Out:
# ('Encoding : ', {'A64': 0, 'A65': 1, 'A61': 2, 'A62': 3, 'A63': 4})

# %%
# the histogram of the categorical data of Attribute 7 -- Good and Bad
print("Encoding : ", integer_map7)

df = pd.DataFrame({'Good':Good["Attribute7"],'Bad':Bad["Attribute7"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute9 ")
plt.ylabel('Present employment since')
plt.xlabel('A72            A74            A73             A71            A75 ')
plt.show()
# Out:
# ('Encoding : ', {'A75': 0, 'A74': 1, 'A73': 2, 'A72': 3, 'A71': 4})

# %%
# the histogram of the categorical data of Attribute 9 -- Good and Bad
print("Encoding : ", integer_map9)

df = pd.DataFrame({'Good':Good["Attribute9"],'Bad':Bad["Attribute9"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute9 Bad")
plt.ylabel('Personal status and sex')
plt.xlabel('A94               A92                A93                      A91    ')
plt.show()
# Out:
# ('Encoding : ', {'A94': 0, 'A91': 1, 'A93': 2, 'A92': 3})

# %%
# the histogram of the categorical data of Attribute 10 -- Good and Bad
print("Encoding : ", integer_map10)

df = pd.DataFrame({'Good':Good["Attribute10"],'Bad':Bad["Attribute10"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute10 Bad")
plt.ylabel('Other debtors / guarantors')
plt.xlabel('A103                              A101                                A102')
plt.show()
# Out:
# ('Encoding : ', {'A102': 0, 'A103': 1, 'A101': 2})

# %%
# the histogram of the categorical data of Attribute 12 -- Good and Bad
print("Encoding : ", integer_map12)

df = pd.DataFrame({'Good':Good["Attribute12"],'Bad':Bad["Attribute12"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute12 Bad")
plt.ylabel('Property')
plt.xlabel('A123                    A121                     A124                A122')
plt.show()
# Out:
# ('Encoding : ', {'A121': 0, 'A122': 1, 'A123': 2, 'A124': 3})

# %%
# the histogram of the categorical data of Attribute 14 -- Good and Bad
print("Encoding : ", integer_map14)

df = pd.DataFrame({'Good':Good["Attribute14"],'Bad':Bad["Attribute14"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute14 Bad")
plt.ylabel('Other installment plans')
plt.xlabel('A141                            A143                              A142')
plt.show()
# Out:
# ('Encoding : ', {'A142': 0, 'A143': 1, 'A141': 2})

# %%
# the histogram of the categorical data of Attribute 15 -- Good and Bad
print("Encoding : ", integer_map15)

df = pd.DataFrame({'Good':Good["Attribute15"],'Bad':Bad["Attribute15"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute15 Bad")
plt.ylabel('Housing')
plt.xlabel('A153                            A152                              A151')
plt.show()
# Out:
# ('Encoding : ', {'A151': 0, 'A153': 1, 'A152': 2})

# %%
# the histogram of the categorical data of Attribute 17 -- Good and Bad
print("Encoding : ", integer_map17)

df = pd.DataFrame({'Good':Good["Attribute17"],'Bad':Bad["Attribute17"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute17 Bad")
plt.ylabel('Job')
plt.xlabel('A172                      A171               A174                   A173')
plt.show()
# Out:
# ('Encoding : ', {'A174': 0, 'A173': 1, 'A172': 2, 'A171': 3})

# %%
# the histogram of the categorical data of Attribute 19 -- Good and Bad
print("Encoding : ", integer_map19)

df = pd.DataFrame({'Good':Good["Attribute19"],'Bad':Bad["Attribute19"]},columns=['Good','Bad'])

df.plot.hist()
plt.title("Histogram for Attribute19 Bad")
plt.ylabel('Telephone')
plt.xlabel('A191                                                           A192')
plt.show()
# Out:
# ('Encoding : ', {'A191': 0, 'A192': 1})

# %%
# the histogram of the categorical data of Attribute 20 -- Good
print("Encoding : ", integer_map20)

plt.hist(Good["Attribute20"], facecolor='green')
plt.title("Histogram for Attribute20 GOOD")
plt.ylabel('Status of existing checking ammount')
plt.xlabel('A201                                                            A202')
plt.show()

# the histogram of the categorical data of Attribute 20 -- Bad
print("Encoding : ", integer_map20)

plt.hist(Bad["Attribute20"], facecolor='green')
plt.title("Histogram for Attribute20 Bad")
plt.ylabel('Status of existing checking ammount')
plt.xlabel('A201                                                           A202')
plt.show()
# Out:
# ('Encoding : ', {'A201': 0, 'A202': 1})
# ('Encoding : ', {'A201': 0, 'A202': 1})

# %% [markdown]
# ### Numerical Data Plots

# %%
# histogram for numerical data of attribute 2
df = pd.DataFrame({'Good': Good['Attribute2'], 'Bad':Bad['Attribute2'] }, columns=['Good' ,'Bad'])
df.plot.box()
plt.title("Box plot for Attribute2 Good, Bad")
plt.ylabel('Duration in month')
plt.show()

# %%
# histogram for numerical data of attribute 5
df = pd.DataFrame({'Good': Good['Attribute5'], 'Bad':Bad['Attribute5'] }, columns=['Good' ,'Bad'])
df.plot.box()
plt.title("Box plot for Attribute5 Good, Bad")
plt.ylabel('Credit amount')
plt.show()

# %%
# histogram for numerical data of attribute 8
df = pd.DataFrame({'Good': Good['Attribute8'], 'Bad':Bad['Attribute8'] }, columns=['Good' ,'Bad'])
df.plot.box()
plt.title("Box plot for Attribute8 Good, Bad")
plt.ylabel('Installment rate in percentage of disposable income')
plt.show()

# %%
# histogram for numerical data of attribute 11
df = pd.DataFrame({'Good': Good['Attribute11'], 'Bad':Bad['Attribute11'] }, columns=['Good' ,'Bad'])
df.plot.box()
plt.title("Box plot for Attribute11 Good, Bad")
plt.ylabel('Present residence since')
plt.show()

# %%
# histogram for numerical data of attribute 13
df = pd.DataFrame({'Good': Good['Attribute13'], 'Bad':Bad['Attribute13'] }, columns=['Good' ,'Bad'])
df.plot.box()
plt.title("Box plot for Attribute13 Good, Bad")
plt.ylabel('Age in years')
plt.show()

# %%
# histogram for numerical data of attribute 16
df = pd.DataFrame({'Good': Good['Attribute16'], 'Bad':Bad['Attribute16'] }, columns=['Good' ,'Bad'])
df.plot.box()
plt.title("Box plot for Attribute16 Good, Bad")
plt.ylabel('Number of existing credits at this bank')
plt.show()

# %%
# histogram for numerical data of attribute 18
df = pd.DataFrame({'Good': Good['Attribute18'], 'Bad':Bad['Attribute18'] }, columns=['Good' ,'Bad'])
df.plot.box()
plt.title("Box plot for Attribute18 Good, Bad")
plt.ylabel('Number of people being liable to provide maintenance for')
plt.show()

# %% [markdown]
# ### Conclusions

# %% [markdown]
# From the categorical data plots, we can assume that features 1, 4, 12 and 17 will be most useful in the customers classification. This is because they present a satisfactory variance between the amount of "Good" and "Bad" customers that they represent. This means that it is safer to make decisions about whether a customer is "Good" or "Bad" based on them, because the possibility that we are right will be better than 50%. Under the same logic, from the numerical data plots, we assume that features 2 and 5 will be most useful in the customers classification. In both cases, we observe that the plots of all the other attributes data, whether they are numerical or categorical, don't really help us to decide whether someone is "Good" or "Bad" based on them, because the "Good" and the "Bad" plots resemble each other, sometimes a lot.
